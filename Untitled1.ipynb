# %%
import pandas as pd
import numpy as np

# %%
basics_url = 'https://datasets.imdbws.com/title.basics.tsv.gz'
akas_url = 'https://datasets.imdbws.com/title.akas.tsv.gz'
ratings_url = 'https://datasets.imdbws.com/title.ratings.tsv.gz'

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
# Replace '\N' with np.nan
basics.replace({'\\N':np.nan}, inplace=True)

# %%
basics.dropna(subset = ["runtimeMinutes"], inplace = True)

# %%
basics["runtimeMinutes"].isnull().sum()
# Out:
# 0

# %%
basics.dropna(subset = ["genres"], inplace = True)

# %%
basics["genres"].isnull().sum()
# Out:
# 0

# %%
basics=basics.loc[(basics["titleType"]=="movie")]

# %%
basics=basics.loc[(basics['startYear']>='1999')]

# %%
basics.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 34805  tt0035423     movie                                     Kate & Leopold
# 61119  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67672  tt0069049     movie                         The Other Side of the Wind
# 77968  tt0079644     movie                                      November 1828
# 86806  tt0088751     movie                                  The Naked Monster
#
#                                    originalTitle isAdult startYear endYear  \
# 34805                             Kate & Leopold       0      2001     NaN
# 61119  El Tango del Viudo y Su Espejo Deformante       0      2020     NaN
# 67672                 The Other Side of the Wind       0      2018     NaN
# 77968                              November 1828       0      2001     NaN
# 86806                          The Naked Monster       0      2005     NaN
#
#       runtimeMinutes                  genres
# 34805            118  Comedy,Fantasy,Romance
# 61119             70                   Drama
# 67672            122                   Drama
# 77968            140               Drama,War
# 86806            100    Comedy,Horror,Sci-Fi

# %%
doc_filter = basics['genres'].str.contains('documentary', case=False)
basics = basics[~doc_filter]

# %%
keepers = basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 34805      True
# 61119      True
# 67672      True
# 77968      True
# 86806      True
#            ...
# 8925869    True
# 8925878    True
# 8925917    True
# 8925962    True
# 8926046    True
# Name: tconst, Length: 142051, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#             tconst titleType  \
# 34805    tt0035423     movie
# 61119    tt0062336     movie
# 67672    tt0069049     movie
# 77968    tt0079644     movie
# 86806    tt0088751     movie
# ...            ...       ...
# 8925869  tt9916170     movie
# 8925878  tt9916190     movie
# 8925917  tt9916270     movie
# 8925962  tt9916362     movie
# 8926046  tt9916538     movie
#
#                                               primaryTitle  \
# 34805                                       Kate & Leopold
# 61119    The Tango of the Widower and Its Distorting Mi...
# 67672                           The Other Side of the Wind
# 77968                                        November 1828
# 86806                                    The Naked Monster
# ...                                                    ...
# 8925869                                      The Rehearsal
# 8925878                                          Safeguard
# 8925917                           Il talento del calabrone
# 8925962                                              Coven
# 8926046                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult startYear endYear  \
# 34805                               Kate & Leopold       0      2001     NaN
# 61119    El Tango del Viudo y Su Espejo Deformante       0      2020     NaN
# 67672                   The Other Side of the Wind       0      2018     NaN
# 77968                                November 1828       0      2001     NaN
# 86806                            The Naked Monster       0      2005     NaN
# ...                                            ...     ...       ...     ...
# 8925869                                   O Ensaio       0      2019     NaN
# 8925878                                  Safeguard       0      2020     NaN
# 8925917                   Il talento del calabrone       0      2020     NaN
# 8925962                                   Akelarre       0      2020     NaN
# 8926046                        Kuambil Lagi Hatiku       0      2019     NaN
#
#         runtimeMinutes                     genres
# 34805              118     Comedy,Fantasy,Romance
# 61119               70                      Drama
# 67672              122                      Drama
# 77968              140                  Drama,War
# 86806              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 8925869             51                      Drama
# 8925878             90  Action,Adventure,Thriller
# 8925917             84                   Thriller
# 8925962             92              Drama,History
# 8926046            123                      Drama
#
# [141421 rows x 9 columns]

# %%
akas.replace({'\\N':np.nan}, inplace=True)

# %%
akas = akas.loc[(akas['region'] == 'US')]

# %%
akas
# Out:
#             titleId  ordering                          title region language  \
# 5         tt0000001         6                     Carmencita     US      NaN
# 14        tt0000002         7         The Clown and His Dogs     US      NaN
# 33        tt0000005        10               Blacksmith Scene     US      NaN
# 36        tt0000005         1            Blacksmithing Scene     US      NaN
# 41        tt0000005         6            Blacksmith Scene #1     US      NaN
# ...             ...       ...                            ...    ...      ...
# 32003030  tt9916702         1  Loving London: The Playground     US      NaN
# 32003068  tt9916720        10                The Demonic Nun     US      NaN
# 32003070  tt9916720        12                      The Nun 2     US      NaN
# 32003087  tt9916756         1       Pretty Pretty Black Girl     US      NaN
# 32003103  tt9916764         1                             38     US      NaN
#
#                 types             attributes isOriginalTitle
# 5         imdbDisplay                    NaN               0
# 14                NaN  literal English title               0
# 33        imdbDisplay                    NaN               0
# 36        alternative                    NaN               0
# 41        alternative                    NaN               0
# ...               ...                    ...             ...
# 32003030  imdbDisplay                    NaN               0
# 32003068           tv                    NaN               0
# 32003070  imdbDisplay                    NaN               0
# 32003087  imdbDisplay                    NaN               0
# 32003103  imdbDisplay                    NaN               0
#
# [1321995 rows x 8 columns]

# %%
ratings.replace({'\\N':np.nan}, inplace=True)

# %%
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1879
# 1        tt0000002            5.9       249
# 2        tt0000003            6.5      1655
# 3        tt0000004            5.8       162
# 4        tt0000005            6.2      2479
# ...            ...            ...       ...
# 1245046  tt9916690            6.5         6
# 1245047  tt9916720            5.2       211
# 1245048  tt9916730            8.7         6
# 1245049  tt9916766            6.7        19
# 1245050  tt9916778            7.2        34
#
# [1245051 rows x 3 columns]

# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# []
